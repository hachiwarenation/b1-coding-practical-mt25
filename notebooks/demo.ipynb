# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# You can double-check your Python path like this...
import sys  

directory_path = "C:/Users/nemom/.vscode/repositories/b1-coding-practical-mt25/uuv_mission"

#sys.path.append(directory_path)
print(sys.path)
from uuv_mission import control
# Out:
# ['C:\\Users\\nemom\\.vscode\\repositories\\b1-coding-practical-mt25', 'c:\\Users\\nemom\\.vscode\\repositories\\b1-coding-practical-mt25\\notebooks', 'C:\\Users\\nemom\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\nemom\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\nemom\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\nemom\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\nemom\\.vscode\\repositories\\b1-coding-practical-mt25\\.venv', '', 'c:\\Users\\nemom\\.vscode\\repositories\\b1-coding-practical-mt25\\.venv\\Lib\\site-packages']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission import dynamic
from uuv_mission import control

sub = dynamic.Submarine()
controller = control.Controller()
# Instantiate your controller (depending on your implementation)
closed_loop = dynamic.ClosedLoop(sub, controller)

mission_path = str(sys.path[0]+"\data\mission.csv")

mission = dynamic.Mission.from_csv(mission_path) # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
